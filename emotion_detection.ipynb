# %%
import pandas as pd
import numpy as np

# %%
emotion_docs=pd.read_csv('/home/emmanuel/workspace/machine_learning/text_emotion.csv')
emotion_docs.head()
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...

# %%
emot_docs=emotion_docs.drop(['tweet_id','author'], axis =1)
emot_docs.head()
# Out:
#     sentiment                                            content
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
sentmt=emot_docs.sentiment.value_counts()
sentmt
# Out:
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: sentiment, dtype: int64

# %%
X=emot_docs.content
X.head()
# Out:
# 0    @tiffanylue i know  i was listenin to bad habi...
# 1    Layin n bed with a headache  ughhhh...waitin o...
# 2                  Funeral ceremony...gloomy friday...
# 3                 wants to hang out with friends SOON!
# 4    @dannycastillo We want to trade with someone w...
# Name: content, dtype: object

# %%
print(X.shape)
# Out:
# (40000,)

# %%
y=emot_docs.sentiment
y.head()
# Out:
# 0         empty
# 1       sadness
# 2       sadness
# 3    enthusiasm
# 4       neutral
# Name: sentiment, dtype: object

# %%
print(y.shape)
# Out:
# (40000,)

# %%
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 82)

# %%
X_train.head()
# Out:
# 17707    @cherylsayshi i thought it was just me that wa...
# 38922    Playing logical gates games with Charles on : ...
# 23663    @iiacovou  hiya!  did you get a picture of you...
# 12399                                  Tom is back in town
# 16922    I want to cry at the thought of the NBA season...
# Name: content, dtype: object

# %%
y_train.head()
# Out:
# 17707       worry
# 38922     neutral
# 23663         fun
# 12399    surprise
# 16922     sadness
# Name: sentiment, dtype: object

# %%
X_test.head()
# Out:
# 6162                      @Willtothe no...i'm just tired..
# 32424    @offgrid Awwww   i've got some photos of cute ...
# 17915    24 hours and $400 later and I hav a new teleco...
# 16358    @bowwow614 I would but I'm afraid I got two le...
# 2560     i lost all my friends, i'm alone and sleepy..i...
# Name: content, dtype: object

# %%
y_test.head()
# Out:
# 6162     neutral
# 32424       love
# 17915       hate
# 16358    sadness
# 2560     sadness
# Name: sentiment, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words='english')

# %%
vect.fit(X_train)
vect.vocabulary_
# Out:
# {'cherylsayshi': 7517,
#  'thought': 36414,
#  'just': 19497,
#  'like': 21425,
#  'really': 29807,
#  'hot': 16844,
#  'room': 30879,
#  'sleep': 33205,
#  'playing': 28230,
#  'logical': 21832,
#  'gates': 14443,
#  'games': 14379,
#  'charles': 7330,
#  'http': 16943,
#  'tinyurl': 36663,
#  'com': 8337,
#  '6jwjmy': 1269,
#  'took': 36896,
#  'mn': 24270,
#  'make': 22576,
#  'light': 21405,
#  'bulb': 6232,
#  'flicker': 13541,
#  'iiacovou': 17334,
#  'hiya': 16548,
#  'did': 10510,
#  'picture': 28002,
#  'converse': 8676,
#  'tom': 36816,
#  'town': 37041,
#  'want': 38997,
#  'nba': 25462,
#  'season': 31949,
#  'year': 40473,
#  'miami': 23677,
#  'morning': 24577,
#  'im': 17416,
#  'ready': 29768,
#  'weeee': 39219,
#  'sunday': 34961,
#  'twitter': 37687,
#  'does': 10997,
#  'talk': 35491,
#  'know': 20401,
#  'celebs': 7118,
#  'nt': 26249,
#  'nice': 25751,
#  'spoken': 34042,
#  'omg': 26662,
#  'july': 19453,
#  'day': 9866,
#  'muchachomalo': 24930,
#  'darkaeon': 9715,
#  'alas': 2295,
#  'best': 4852,
#  'offer': 26473,
#  'small': 33314,
#  'pony': 28442,
#  'rowing': 30983,
#  'boat': 5411,
#  'letteapplejuice': 21272,
#  'heckitty': 16175,
#  'forget': 13778,
#  'aussies': 3842,
#  'online': 26719,
#  'check': 7415,
#  'today': 36771,
#  'tonight': 36870,
#  'channel': 7271,
#  'handsome': 15822,
#  'man': 22654,
#  'writing': 40033,
#  'don': 11059,
#  'think': 36349,
#  'lol': 21845,
#  'read': 29760,
#  'pretty': 28792,
#  'damn': 9556,
#  'good': 15030,
#  'phone': 27919,
#  'kayla': 19848,
#  'johnathan': 19094,
#  'cisco': 7891,
#  'woo': 39844,
#  'went': 39319,
#  'green': 15321,
#  'yesterday': 40548,
#  'missed': 24076,
#  'certificate': 7171,
#  'gain': 14343,
#  'weight': 39260,
#  'lost': 21997,
#  '20': 312,
#  'pounds': 28606,
#  '108': 81,
#  '23': 373,
#  'yrs': 40711,
#  'old': 26616,
#  'healthy': 16109,
#  'smile': 33356,
#  'follow': 13687,
#  'perfectgrrl85': 27724,
#  'dont': 11106,
#  'need': 25503,
#  'plant': 28193,
#  'll': 21731,
#  'hug': 16965,
#  'instead': 17774,
#  'hugs': 16980,
#  'gonna': 15027,
#  'stop': 34549,
#  'kevinpollak': 20043,
#  'forgive': 13782,
#  'hahaha': 15683,
#  'yay': 40432,
#  'emily': 12121,
#  'cool': 8705,
#  'emilystack': 12129,
#  'bday': 4535,
#  'weekend': 39230,
#  'shit': 32581,
#  'headed': 16079,
#  'south': 33805,
#  'drive': 11364,
#  'atl': 3725,
#  'nap': 25339,
#  'beach': 4542,
#  'jonasfanjade': 19171,
#  'ok2': 26591,
#  'nyt': 26345,
#  'haha': 15676,
#  'early': 11652,
#  'katiekins08': 19798,
#  'sooooooo': 33703,
#  'bad': 4161,
#  'getting': 14671,
#  'meet': 23360,
#  'laura': 20945,
#  'training': 37125,
#  'sick': 32799,
#  'martinb9999': 22948,
#  'intel': 17799,
#  'based': 4404,
#  'mac': 22405,
#  '1st': 294,
#  'impacts': 17484,
#  'dual': 11448,
#  'core': 8757,
#  'vs': 38834,
#  'quad': 29312,
#  'choice': 7686,
#  'probably': 28901,
#  'better': 4881,
#  'virtualization': 38667,
#  'egg': 11880,
#  'whites': 39478,
#  'grain': 15224,
#  'toast': 36756,
#  'yup': 40753,
#  'alsotop': 2563,
#  'drool': 11383,
#  '100': 55,
#  'johnhlynn': 19109,
#  'let': 21261,
#  'upload': 38185,
#  'pic': 27978,
#  'pc': 27555,
#  'clear': 8025,
#  'intellectually': 17800,
#  'severing': 32189,
#  'relationship': 30107,
#  'heart': 16119,
#  'complete': 8462,
#  'disagreement': 10671,
#  'hurts': 17058,
#  'ooo': 26757,
#  'goddddd': 14978,
#  'vodafone': 38763,
#  'trouble': 37356,
#  'network': 25640,
#  'shot': 32686,
#  'ow': 27082,
#  'teeth': 35802,
#  'head': 16071,
#  'carlosv': 6834,
#  'np': 26233,
#  'got': 15119,
#  'working': 39923,
#  'series': 32140,
#  'designs': 10333,
#  'work': 39911,
#  'bed': 4658,
#  'thinking': 36354,
#  'funny': 14215,
#  'stuff': 34727,
#  'night': 25843,
#  'times': 36609,
#  'umm': 37938,
#  'yeaa': 40456,
#  'watch': 39067,
#  'movies': 24687,
#  'link': 21539,
#  'quality': 29320,
#  'supernatural': 35028,
#  'loved': 22059,
#  'ankitbathija': 3007,
#  'thanks': 36012,
#  'mate': 23037,
#  'came': 6640,
#  'board': 5403,
#  'tweet': 37567,
#  'sounds': 33794,
#  'great': 15297,
#  'moring': 24569,
#  'shower': 32710,
#  'fix': 13457,
#  'hair': 15718,
#  'going': 15001,
#  'joyofzen': 19307,
#  'doing': 11017,
#  'okay': 26598,
#  'love': 22049,
#  'music': 25047,
#  'video': 38589,
#  'belong': 4772,
#  'taylor': 35672,
#  'excitement': 12707,
#  'new': 25662,
#  'followers': 13691,
#  'overnight': 27053,
#  'sadness': 31301,
#  'ad': 1833,
#  'bots': 5647,
#  'quiet': 29383,
#  'jealous': 18583,
#  'clearly': 8029,
#  'having': 16015,
#  'exciting': 12708,
#  'life': 21378,
#  'alloverart': 2484,
#  'apartment': 3207,
#  'nothin': 26174,
#  'little': 21634,
#  'hungry': 17030,
#  'myloc': 25154,
#  'fim': 13346,
#  'photomedia': 27943,
#  'assignment': 3669,
#  'thanku': 36016,
#  'mum': 24978,
#  'tea': 35723,
#  'making': 22585,
#  'feel': 13161,
#  'clean': 8014,
#  'youtube': 40692,
#  'fail': 12915,
#  'right': 30572,
#  'maybe': 23160,
#  'hates': 15984,
#  'birthday': 5086,
#  'happy': 15884,
#  'taking': 35475,
#  'break': 5820,
#  'cell': 7128,
#  'dying': 11603,
#  'bbc_fangirl': 4495,
#  'won': 39819,
#  'states': 34318,
#  'boo': 5510,
#  'kick': 20115,
#  'butt': 6379,
#  'jonasbrothers': 19169,
#  'guys': 15600,
#  'didn': 10516,
#  'say': 31661,
#  'hi': 16419,
#  'answer': 3108,
#  'questions': 29368,
#  'songs': 33666,
#  'pulled': 29150,
#  'interesting': 17820,
#  'meeting': 23362,
#  'urgent': 38230,
#  'support': 35054,
#  'request': 30287,
#  'webcams': 39184,
#  'hoepfner': 16593,
#  'burgfest': 6305,
#  'karlsruhe': 19714,
#  'automatic': 3869,
#  'reload': 30149,
#  'bit': 5101,
#  'ly': 22322,
#  'vdtvf': 38434,
#  'don_iain': 11060,
#  'team': 35734,
#  'couldn': 8846,
#  've': 38435,
#  'nudged': 26264,
#  'lately': 20909,
#  'umped': 37945,
#  'wknd': 39757,
#  'pills': 28046,
#  'loving': 22114,
#  'learn': 21096,
#  'try': 37408,
#  'live': 21666,
#  'bratinella': 5794,
#  'madsdeguzman': 22486,
#  'muji': 24965,
#  'stabilo': 34199,
#  'eyeing': 12845,
#  'week': 39224,
#  'time': 36600,
#  'oh': 26519,
#  'wish': 39710,
#  'laying': 21028,
#  'joined': 19133,
#  'cestcassie': 7176,
#  'aw': 3920,
#  'song': 33659,
#  'makes': 22580,
#  'girl': 14807,
#  'scouts': 31847,
#  'installed': 17764,
#  'netgear': 25626,
#  '802': 1342,
#  '11n': 112,
#  'draft': 11262,
#  'router': 30972,
#  'throughput': 36457,
#  'definately': 10118,
#  'increased': 17575,
#  'trying': 37411,
#  'figure': 13310,
#  'perfect': 27723,
#  'way': 39118,
#  'leading': 21073,
#  'principled': 28860,
#  'listening': 21613,
#  'commentary': 8388,
#  'track': 37075,
#  'holiday': 16625,
#  'inn': 17703,
#  'bing': 5053,
#  'crosby': 9131,
#  'black': 5154,
#  'face': 12877,
#  'rest': 30351,
#  'movie': 24683,
#  'cute': 9354,
#  'macquid': 22436,
#  'soetimes': 33572,
#  'envy': 12327,
#  'spent': 33962,
#  'lives': 21683,
#  'place': 28170,
#  'deep': 10088,
#  'roots': 30896,
#  'grass': 15270,
#  'syndrome': 35367,
#  'train': 37121,
#  'late': 20907,
#  'starts': 34300,
#  '15': 172,
#  'mins': 23974,
#  'arriving': 3483,
#  'london': 21878,
#  'miss': 24043,
#  'stylenista': 34755,
#  'class': 7983,
#  'hours': 16874,
#  'played': 28220,
#  'game': 14370,
#  'yeahhhhh': 40468,
#  'inlove': 17699,
#  'ughh': 37874,
#  'cause': 7017,
#  'fool': 13731,
#  'tired': 36674,
#  'laughing': 20933,
#  'till': 36591,
#  'stomache': 34531,
#  'lots': 22012,
#  '2do': 437,
#  'usual': 38276,
#  'laundry': 20944,
#  'thanking': 36011,
#  'god': 14967,
#  'cleaning': 8021,
#  'house': 16876,
#  'praising': 28671,
#  'cutting': 9372,
#  'hedge': 16182,
#  'yoscottie': 40646,
#  'btw': 6130,
#  'everytime': 12639,
#  'ur': 38214,
#  'smiling': 33367,
#  'profile': 28947,
#  'quot': 29408,
#  'grins': 15405,
#  'enjoying': 12267,
#  'spring': 34094,
#  'sunshine': 34995,
#  'streaming': 34624,
#  'window': 39656,
#  'woke': 39791,
#  '5am': 992,
#  'rigid': 30575,
#  'extreme': 12829,
#  'pain': 27195,
#  'exhausted': 12728,
#  'positive': 28549,
#  'rupert_grint': 31144,
#  'dog': 11002,
#  'thingy': 36347,
#  'adorable': 1933,
#  'golden': 15008,
#  'retriever': 30403,
#  'awesome': 3950,
#  'husky': 17064,
#  'abaggy': 1604,
#  'yeah': 40464,
#  'embedded': 12096,
#  'staff': 34225,
#  'recognize': 29894,
#  'emails': 12078,
#  'doonytime': 11134,
#  'minstrels': 23975,
#  'grab': 15178,
#  'petrol': 27818,
#  'station': 34322,
#  'delicious': 10172,
#  'sickkk': 32806,
#  'days': 9876,
#  'summer': 34920,
#  'started': 34295,
#  'suck': 34814,
#  'joycescapade': 19297,
#  'coooooooool': 8721,
#  'dooooooooown': 11139,
#  'patience': 27450,
#  'virtue': 38670,
#  'zownder': 40921,
#  'hahah': 15682,
#  'tradewinds': 37099,
#  'odyssey': 26456,
#  'bump': 6265,
#  'kerrianson': 20009,
#  'catching': 6979,
#  'relaxing': 30119,
#  'kind': 20212,
#  'lazy': 21038,
#  'hehe': 16210,
#  'oooo': 26763,
#  'shopping': 32655,
#  'resist': 30327,
#  'car': 6774,
#  'giving': 14851,
#  'problems': 28907,
#  'sign': 32849,
#  'apt10c': 3317,
#  'walking': 38959,
#  'home': 16670,
#  'fell': 13188,
#  'ground': 15439,
#  'tahninial': 35450,
#  'called': 6601,
#  'cheeseburglar': 7447,
#  'sad': 31282,
#  'push': 29219,
#  'amazing': 2654,
#  'chris': 7720,
#  'pine': 28063,
#  'zachary': 40791,
#  'quinto': 29397,
#  'leonard': 21230,
#  'nimoy': 25909,
#  'snl': 33473,
#  'quite': 29401,
#  'possibly': 28560,
#  'fun': 14177,
#  'geeking': 14517,
#  'long': 21891,
#  'adamjackson': 1845,
#  'macbook': 22414,
#  'keyboard': 20055,
#  'spilled': 33987,
#  'cup': 9287,
#  'chocolate': 7673,
#  'realized': 29793,
#  'fully': 14175,
#  'feelin': 13162,
#  'nutt': 26310,
#  'collar': 8295,
#  'leash': 21105,
#  'apps': 3301,
#  'facebook': 12880,
#  'dogbook': 11003,
#  'view': 38607,
#  '1034415': 71,
#  'twitpic': 37678,
#  '4wk9i': 890,
#  'different': 10539,
#  'pose': 28542,
#  'ofcourse': 26465,
#  'wait': 38916,
#  'minute': 23985,
#  'run': 31123,
#  'experiment': 12774,
#  'supervise': 35040,
#  'aka': 2252,
#  'leave': 21109,
#  'vestacaro': 38527,
#  'tax': 35661,
#  'money': 24433,
#  'helio': 16246,
#  'winning': 39682,
#  'pole': 28402,
#  'position': 28547,
#  'ha': 15631,
#  'computer': 8490,
#  'held': 16231,
#  'hostage': 16839,
#  'parents': 27351,
#  'pick': 27982,
#  'friday': 14029,
#  'guess': 15522,
#  'freaky': 13936,
#  'gah': 14325,
#  'left': 21149,
#  'glasses': 14884,
#  'reading': 29766,
#  'headache': 16074,
#  'believe': 4736,
#  'age': 2065,
#  'sleeper': 33207,
#  'designsbyvaleri': 10334,
#  'excellent': 12695,
#  'designers': 10329,
#  'valerie': 38368,
#  'boonewallbeds': 5552,
#  'backstreetboys': 4147,
#  '3x3wq': 629,
#  'impossible': 17505,
#  'closely': 8101,
#  'arcadianlady': 3357,
#  'eek': 11840,
#  'elses': 12055,
#  'gahh': 14330,
#  'soniei': 33675,
#  'argh': 3392,
#  'ebay': 11704,
#  'outbid': 26976,
#  'second': 31963,
#  'liz920': 21700,
#  'notice': 26179,
#  'dance': 9587,
#  'rain': 29549,
#  'outta': 27007,
#  '2morrow': 464,
#  'sat': 31607,
#  'saturday': 31620,
#  'shift': 32528,
#  'jzwack': 19573,
#  'forum': 13818,
#  'access': 1727,
#  'away': 3938,
#  'beauknows': 4598,
#  'luck': 22180,
#  'stupid': 34742,
#  'paper': 27307,
#  'worries': 39952,
#  'record': 29911,
#  'album': 2305,
#  'jakeron': 18298,
#  'interaction': 17814,
#  'feet': 13170,
#  'hurt': 17053,
#  'finally': 13356,
#  'crunch': 9169,
#  'productive': 28934,
#  'mm': 24246,
#  'cold': 8267,
#  'shadow': 32255,
#  'ooh': 26750,
#  'monday': 24428,
#  'far': 13016,
#  'wanna': 38993,
#  'frighten': 14056,
#  'death': 9986,
#  'boys': 5705,
#  'leathers': 21108,
#  'brilliant': 5942,
#  'atmos': 3740,
#  'd6smh5': 9463,
#  'painthing': 27209,
#  'cynthiay29': 9431,
#  'info': 17655,
#  'forwarded': 13821,
#  'needy': 25513,
#  'friend': 14036,
#  'melodykid': 23483,
#  'ahhh': 2146,
#  'gone': 15025,
#  'brittaniethekid': 5972,
#  'aaah': 1558,
#  'bye': 6440,
#  'mikee': 23831,
#  'smoked': 33377,
#  'crabs': 8949,
#  'snap': 33426,
#  'breaking': 5830,
#  'mitchelmusso': 24186,
#  'loads': 21789,
#  'amp': 2755,
#  'people': 27700,
#  'asking': 3633,
#  'al': 2276,
#  'seriously': 32145,
#  'wonder': 39821,
#  'comments': 8391,
#  'realhughjackman': 29782,
#  'wolverine': 39807,
#  'actor': 1819,
#  'icon': 17238,
#  'eff': 11861,
#  'later': 20910,
#  'worried': 39951,
#  'sister': 33010,
#  'guinea': 15542,
#  'pig': 28020,
#  'hope': 16770,
#  'stalin': 34239,
#  'baby': 4086,
#  'mavinbkk': 23134,
#  'feels': 13167,
#  'ages': 2082,
#  'months': 24487,
#  'moi_uae': 24342,
#  'wth': 40058,
#  '9_9': 1419,
#  'hello': 16263,
#  'levitte': 21291,
#  'excited': 12703,
#  'cut': 9352,
#  'todayyyy': 36777,
#  'nerrrvous': 25599,
#  'wake': 38928,
#  'december': 10034,
#  'organized': 26898,
#  'feeling': 13163,
#  'poo': 28446,
#  'anncurry': 3037,
#  'photos': 27944,
#  'subject': 34774,
#  'educated': 11806,
#  'darfur': 9708,
#  'inspiring': 17759,
#  'woman': 39811,
#  'celticfish': 7135,
#  'travesty': 37193,
#  'ego_assassin': 11886,
#  'soooo': 33698,
#  'sorry': 33758,
#  'kitties': 20297,
#  'asleep': 3636,
#  'halestormrocks': 15745,
#  'unfortunately': 38042,
#  'able': 1658,
#  'gotta': 15135,
#  '2nd': 470,
#  'gig': 14742,
#  'mileycyrus': 23875,
#  'hey': 16366,
#  'la': 20656,
#  'favorite': 13094,
#  'bout': 5673,
#  'europe': 12577,
#  'country': 8861,
#  'xcept': 40198,
#  'canada': 6680,
#  'xo': 40258,
#  'jenna': 18669,
#  'wee': 39212,
#  'bgt': 4929,
#  'xx': 40316,
#  'sucha': 34813,
#  'shame': 32297,
#  'kicked': 20118,
#  'school': 31775,
#  'thing': 36340,
#  'job': 19015,
#  'city': 7901,
#  'weddingsites': 39202,
#  'problem': 28904,
#  'idea': 17249,
#  'course': 8877,
#  'gourmetcook': 15145,
#  'wouldn': 39977,
#  'help': 16290,
#  'voice': 38772,
#  'lt': 22154,
#  'zanna85': 40819,
#  'save': 31639,
#  'snoops': 33480,
#  'uncle': 37973,
#  'coolest': 8709,
#  'dancer': 9591,
#  '4wfqn': 872,
#  'micar': 23690,
#  'gets': 14665,
#  's4': 31242,
#  'cast': 6954,
#  'dropped': 11389,
#  'lancey': 20807,
#  'cook': 8690,
#  'coffee': 8236,
#  'sociology': 33555,
#  'mothers': 24634,
#  'rebuilding': 29859,
#  'dev': 10383,
#  'machine': 22424,
#  'disk': 10739,
#  'crash': 8996,
#  'kimberly625': 20183,
#  'hmmm': 16564,
#  'sleeping': 33210,
#  'videos': 38595,
#  'tomorrow': 36844,
#  'beadqueen': 4551,
#  'doesn': 10998,
#  'sound': 33789,
#  'mariahcarey': 22812,
#  'million': 23894,
#  'plus': 28315,
#  'appreciate': 3286,
#  'choose': 7697,
#  'happieness': 15875,
#  'kritm': 20537,
#  'awe': 3942,
#  'true': 37379,
#  'drea3000_bbcrew': 11300,
#  'dude': 11481,
#  'sleepy': 33217,
#  'soon': 33691,
#  'whhaacck': 39441,
#  'arcania': 3358,
#  'setting': 32175,
#  '600': 1088,
#  'mile': 23868,
#  'hoping': 16787,
#  'goes': 14994,
#  'quickly': 29377,
#  'forth': 13813,
#  'yes': 40532,
#  'star': 34269,
#  'wars': 39041,
#  'aren': 3378,
#  'lucky': 22188,
#  'fans': 13005,
#  'carlton': 6836,
#  'greenville': 15341,
#  'benz': 4825,
#  'serviced': 32155,
#  'sales': 31354,
#  'calls': 6611,
#  'driving': 11371,
#  'carsick': 6891,
#  'macabre': 22406,
#  'hard': 15898,
#  'real': 29774,
#  'nuclear': 26261,
#  'weapon': 39154,
#  'japanese': 18418,
#  'humans': 16997,
#  '9nru': 1425,
#  'warisfucked': 39017,
#  'victoria': 38578,
#  'stress': 34642,
#  'fend': 13208,
#  'crying': 9188,
#  'tuesday': 37466,
#  'cos': 8804,
#  'economics': 11740,
#  'offically': 26481,
#  'jaiash': 18271,
#  'anytime': 3187,
#  'giggles': 14745,
#  'chrisfromracine': 7740,
#  'sure': 35079,
#  'intentionally': 17811,
#  'turn': 37501,
#  'processes': 28913,
#  'silly': 32888,
#  'jenny': 18699,
#  'come': 8353,
#  'cashcapone': 6924,
#  'cash': 6922,
#  'kno': 20388,
#  'hater': 15982,
#  'jus': 19492,
#  'upset': 38198,
#  'update': 38175,
#  'demijonasmexico': 10205,
#  'yn': 40598,
#  'beach_girl3': 4543,
#  'awww': 3988,
#  'party': 27393,
#  'invite': 17906,
#  'nan': 25310,
#  'mother': 24630,
#  'lunch': 22256,
#  'favecolourpink': 13089,
#  'dianaray1': 10486,
#  'iamepiclyamazin': 17143,
#  'told': 36811,
#  'couple': 8866,
#  'weeks': 39235,
#  'ago': 2099,
#  'apart': 3206,
#  'ones': 26709,
#  'vimoh': 38624,
#  'iamdiddy': 17141,
#  '26': 404,
#  'questionable': 29367,
#  'liked': 21427,
#  'regarde': 30046,
#  'les': 21240,
#  'tant': 35552,
#  'attendues': 3770,
#  'photographies': 27938,
#  'attending': 3769,
#  'matthew': 23087,
#  'senior': 32071,
#  'recognition': 29893,
#  'dchi606': 9925,
#  'sadly': 31300,
#  'stanley': 34264,
#  'steemer': 34363,
#  '800': 1339,
#  'number': 26277,
#  'richardmadeley': 30527,
#  'final': 13350,
#  'msg': 24852,
#  'review': 30437,
#  'boardgame': 5405,
#  'bookchaseï': 5531,
#  'telly': 35845,
#  'letter': 21273,
#  'mimi': 23911,
#  'battle': 4462,
#  'minas': 23923,
#  'tirith': 36681,
#  'impressive': 17511,
#  'return': 30412,
#  'jedi': 18597,
#  'lord': 21963,
#  'rings': 30598,
#  'imo': 17477,
#  'blood': 5313,
#  'taken': 35468,
#  'following': 13700,
#  'chester': 7526,
#  'bennington': 4814,
#  'mean': 23284,
#  'dall': 9532,
#  '9am': 1420,
#  'wanted': 38998,
#  '30': 503,
#  'wasn': 39053,
#  'princesssuperc': 28854,
#  'awwwww': 3991,
#  'busyellebee': 6364,
#  'anti': 3133,
#  'understood': 38014,
#  'message': 23583,
#  'vote': 38806,
#  'bnp': 5396,
#  'end': 12217,
#  'space': 33840,
#  'therealsavannah': 36262,
#  'followfriday': 13695,
#  't_1001': 35391,
#  'cuz': 9380,
#  'ive': 18149,
#  'added': 1862,
#  'alexalltimelow': 2335,
#  'aww': 3985,
#  'sydney': 35341,
#  'tickets': 36525,
#  'tho': 36385,
#  'xxx': 40343,
#  'oooh': 26759,
#  'yeaah': 40462,
#  'fooood': 13737,
#  'seat': 31952,
#  'bbq': 4507,
#  'food': 13722,
#  'hahaa': 15677,
#  'mom': 24371,
#  'imma': 17461,
#  'post': 28562,
#  'mommy': 24396,
#  'onchmovement': 26702,
#  'kinda': 20213,
#  'hating': 15987,
#  'overcast': 27031,
#  'weather': 39167,
#  'hate': 15976,
#  'daisy': 9519,
#  'attacked': 3757,
#  'doggie': 11004,
#  'park': 27358,
#  'dads': 9495,
#  'losing': 21993,
#  'mentaly': 23536,
#  'dosent': 11173,
#  'remeber': 30164,
#  'cristalthegreat': 9111,
#  'ok': 26590,
#  'cristal': 9110,
#  'sweetie': 35258,
#  'tweethug': 37588,
#  'ya': 40364,
#  'bust_magazine': 6359,
#  'thats': 36047,
#  'dream': 11308,
#  'reality': 29789,
#  'cs4': 9208,
#  'wishlist': 39719,
#  'bathroom': 4447,
#  'hear': 16114,
#  'gently': 14597,
#  'running': 31134,
#  'water': 39080,
#  'girlies': 14815,
#  'veeveebombshell': 38446,
#  'reesecromwell': 30004,
#  'leavin': 21113,
#  'vanessa': 38393,
#  'reese': 30003,
#  'melluffsyew': 23475,
#  'note': 26166,
#  'self': 32032,
#  'eeeeeewwwwwwww': 11826,
#  'bbc': 4492,
#  'malaria': 22594,
#  'parasites': 27336,
#  'resistant': 30329,
#  'drugs': 11410,
#  'trunc': 37395,
#  '9yn5': 1433,
#  'affects': 2010,
#  'definitely': 10121,
#  'spill': 33986,
#  'canvas': 6735,
#  'seeing': 31994,
#  'stitches': 34512,
#  'ooooover': 26773,
#  'oooover': 26774,
#  'putting': 29236,
#  'suit': 34885,
#  'jeans': 18595,
#  'heading': 16084,
#  'deal': 9958,
#  'family': 12973,
#  'emergency': 12113,
#  'plez': 28285,
#  'pray': 28685,
#  '4us': 808,
#  '630p': 1112,
#  'willing': 39622,
#  'isn': 18035,
#  '00': 0,
#  'struggling': 34692,
#  'nola': 26063,
#  'dad': 9489,
#  'joe': 19038,
#  'nugent': 26266,
#  'drank': 11280,
#  'nearly': 25489,
#  'ice': 17216,
#  'miffed': 23787,
#  'tbh': 35694,
#  'fed': 13145,
#  'badly': 4182,
#  'botcon': 5640,
#  'yaaw': 40376,
#  '5529634599': 976,
#  'jenniferdodd': 18686,
#  'watching': 39074,
#  'disney': 10749,
#  'vcr': 38433,
#  'anymore': 3180,
#  'jennavontweet': 18678,
#  'ohhh': 26534,
#  'french': 13989,
#  'tip': 36665,
#  ...}

# %%
X_train_transformed = vect.transform(X_train)
X_test_transformed =vect.transform(X_test)

# %%
print(type(X_train_transformed))
print(X_train_transformed)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 7517)	1
#   (0, 16844)	2
#   (0, 19497)	1
#   (0, 21425)	1
#   (0, 29807)	1
#   (0, 30879)	1
#   (0, 33205)	1
#   (0, 36414)	1
#   (1, 1269)	1
#   (1, 6232)	1
#   (1, 7330)	2
#   (1, 8337)	1
#   (1, 13541)	1
#   (1, 14379)	1
#   (1, 14443)	1
#   (1, 16943)	1
#   (1, 21405)	1
#   (1, 21832)	1
#   (1, 22576)	1
#   (1, 24270)	1
#   (1, 28230)	1
#   (1, 36663)	1
#   (1, 36896)	1
#   (2, 8676)	2
#   (2, 10510)	1
#   :	:
#   (31996, 25662)	2
#   (31996, 36204)	1
#   (31996, 37411)	1
#   (31996, 37687)	1
#   (31997, 100)	1
#   (31997, 515)	1
#   (31997, 2870)	1
#   (31997, 11652)	1
#   (31997, 22049)	1
#   (31997, 25843)	1
#   (31997, 25862)	1
#   (31997, 39118)	1
#   (31998, 13163)	1
#   (31998, 22230)	1
#   (31998, 25531)	1
#   (31998, 29152)	1
#   (31998, 34995)	1
#   (31998, 38015)	1
#   (31999, 4079)	1
#   (31999, 13782)	1
#   (31999, 18375)	1
#   (31999, 21634)	1
#   (31999, 30602)	1
#   (31999, 36600)	1
#   (31999, 36828)	1

# %%
from sklearn.svm import SVC
svcclassifier = SVC(kernel = 'linear', random_state = 1)
svcclassifier.fit(X_train_transformed, y_train)
# Out:
# SVC(kernel='linear', random_state=1)

# %%
y_pred = svcclassifier.predict(X_test_transformed)
print(y_pred)
# Out:
# ['neutral' 'love' 'hate' ... 'worry' 'neutral' 'neutral']

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.326
